# %%
import FinanceDataReader as fdr

# %%
fdr.__version__
# Out:
# '0.9.6'

# %%
# 한국거래소 상장종목 전체
df_krx = fdr.StockListing('KRX')
df_krx
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-18-3e6372a2eaf8> in <module>
#       1 # 한국거래소 상장종목 전체
# ----> 2 df_krx = fdr.StockListing('KRX')
#       3 df_krx
#
# ~\anaconda3\envs\py37_32\lib\site-packages\FinanceDataReader\data.py in StockListing(market)
#      37         return NasdaqStockListing(market=market).read()
#      38     if market in [ 'KRX', 'KOSPI', 'KOSDAQ', 'KONEX']:
# ---> 39         return KrxStockListing(market).read()
#      40     if market in [ 'KRX-DELISTING' ]:
#      41         return KrxDelisting(market).read()
#
# ~\anaconda3\envs\py37_32\lib\site-packages\FinanceDataReader\krx\listing.py in read(self)
#      37         }
#      38         r = requests.post(down_url, down_data, headers=header_data)
# ---> 39         jo = json.loads(r.text)
#      40         df_finder = json_normalize(jo, 'block1')
# ...

# %%
# S&P 500 종목 전체
df_spx = fdr.StockListing('S&P500')
df_spx.head()
# Out:
#   Symbol                 Name                  Sector  \
# 0    MMM           3M Company             Industrials
# 1    ABT  Abbott Laboratories             Health Care
# 2   ABBV          AbbVie Inc.             Health Care
# 3   ABMD          ABIOMED Inc             Health Care
# 4    ACN        Accenture plc  Information Technology
#
#                          Industry
# 0        Industrial Conglomerates
# 1           Health Care Equipment
# 2                 Pharmaceuticals
# 3           Health Care Equipment
# 4  IT Consulting & Other Services

# %%
# 신라젠, 2018년
dfs = fdr.DataReader('215600', '2020-04-27')
dfs
# Out:
#              Open   High    Low  Close   Volume    Change
# Date
# 2020-04-27  12850  13350  12700  13100  4263453  0.060729
# 2020-04-28  13900  14000  12800  12850  3824540 -0.019084
# 2020-04-29  12900  13050  12400  12600  1810049 -0.019455
# 2020-05-04  12200  12400  11900  12100  1785522 -0.039683
# 2020-05-06      0      0      0  12100        0  0.000000
# ...           ...    ...    ...    ...      ...       ...
# 2020-09-18      0      0      0  12100        0  0.000000
# 2020-09-21      0      0      0  12100        0  0.000000
# 2020-09-22      0      0      0  12100        0  0.000000
# 2020-09-23      0      0      0  12100        0  0.000000
# 2020-09-24      0      0      0  12100        0  0.000000
#
# [105 rows x 6 columns]

# %%
import investpy

# %%
# Retrieve the recent historical data (past month) of a stock as a pandas.DataFrame on ascending date order
df = investpy.get_stock_recent_data(stock='019170', country='south korea', as_json=False, order='ascending')
df.head()
# Out:
#                 Open      High       Low     Close   Volume Currency
# Date
# 2020-08-24   94300.0  102000.0   91900.0  100500.0     3458      KRW
# 2020-08-25  101000.0  122000.0   99000.0  114000.0      345      KRW
# 2020-08-26  118000.0  127000.0  107000.0  113000.0      208      KRW
# 2020-08-27  117000.0  119000.0  109000.0  111500.0     1170      KRW
# 2020-08-28  109500.0  115000.0  105500.0  111000.0  1880984      KRW

# %%
#신라젠
df = investpy.get_stock_historical_data(stock='215600',
                                        country='south korea',
                                        from_date='01/01/1900',
                                        to_date='23/09/2020')

# %%
df
# Out:
#                Open     High      Low    Close   Volume Currency
# Date
# 2016-12-07  12750.0  13150.0  11750.0  11800.0  4218734      KRW
# 2016-12-08  11850.0  12300.0  10900.0  11200.0  4457692      KRW
# 2016-12-09  11350.0  12300.0  11250.0  11900.0  3911415      KRW
# 2016-12-11  11900.0  11900.0  11900.0  11900.0     1242      KRW
# 2016-12-12  12150.0  12300.0  11450.0  11550.0  1695126      KRW
# ...             ...      ...      ...      ...      ...      ...
# 2020-04-27  12850.0  13350.0  12700.0  13100.0  4184267      KRW
# 2020-04-28  13900.0  14000.0  12800.0  12850.0  3802279      KRW
# 2020-04-29  12900.0  13050.0  12400.0  12600.0  1782228      KRW
# 2020-05-03  12600.0  12600.0  12600.0  12600.0        0      KRW
# 2020-05-04  12200.0  12400.0  11900.0  12100.0  1768948      KRW
#
# [984 rows x 6 columns]

# %%
df = fdr.DataReader('USD/KRW', '1995')
df['Close'].plot()

# %%
df
# Out:
#               Close     Open     High      Low  Change
# Date
# 1995-01-02   788.50   788.50   788.50   788.50  0.0000
# 1995-01-03   788.65   788.05   788.85   787.55  0.0002
# 1995-01-04   789.95   788.65   790.05   788.45  0.0016
# 1995-01-05   789.90   789.80   790.20   789.30 -0.0001
# 1995-01-06   791.55   789.75   791.65   789.65  0.0021
# ...             ...      ...      ...      ...     ...
# 2020-09-18  1164.81  1169.70  1170.78  1159.40 -0.0038
# 2020-09-21  1163.61  1165.00  1168.31  1156.46 -0.0010
# 2020-09-22  1163.61  1164.84  1166.03  1158.93  0.0000
# 2020-09-23  1170.65  1163.65  1172.46  1160.69  0.0061
# 2020-09-24  1173.41  1170.63  1174.78  1167.50  0.0024
#
# [6704 rows x 5 columns]

# %%
# investpy.technical 모듈
data = investpy.moving_averages(name='035720', country='south korea', product_type='stock', interval='daily')
data.head()
# Out:
#   period  sma_value sma_signal    ema_value ema_signal
# 0      5   361600.0       sell  360925.9341       sell
# 1     10   368350.0       sell  367890.8020       sell
# 2     20   380950.0       sell  373189.1086       sell
# 3     50   373310.0       sell  364646.9523       sell
# 4    100   331035.0        buy  330740.3452        buy

# %%
# investpy.new 모듈
data = investpy.economic_calendar()
data.head()
# Out:
#        id        date     time           zone currency importance  \
# 0     115  24/09/2020  All Day        namibia     None       None
# 1     115  24/09/2020  All Day   south africa     None       None
# 2  415232  24/09/2020    00:00  united states      USD        low
# 3  415302  24/09/2020    01:00  united states      USD     medium
# 4  414994  24/09/2020    02:00  united states      USD        low
#
#                                 event  actual forecast previous
# 0              Namibia - Heritage Day    None     None     None
# 1         South Africa - Heritage Day    None     None     None
# 2  Chicago Fed President Evans Speaks    None     None     None
# 3        FOMC Member Rosengren Speaks    None     None     None
# 4                 5-Year Note Auction  0.275%     None   0.298%

# %%
investpy.news.economic_calendar(time_zone=None, time_filter='time_only', countries=None, importances=None, categories=None, from_date=None, to_date=None)
# Out:
#         id        date     time           zone currency importance  \
# 0      115  24/09/2020  All Day        namibia     None       None
# 1      115  24/09/2020  All Day   south africa     None       None
# 2   415232  24/09/2020    00:00  united states      USD        low
# 3   415302  24/09/2020    01:00  united states      USD     medium
# 4   414994  24/09/2020    02:00  united states      USD        low
# ..     ...         ...      ...            ...      ...        ...
# 56  415172  24/09/2020    23:00  united states      USD       high
# 57  413713  24/09/2020    23:00  united states      USD     medium
# 58  413714  24/09/2020    23:00  united states      USD       high
# 59  415173  24/09/2020    23:00  united states      USD     medium
# 60  415003  24/09/2020    23:30  united states      USD        low
#
#                                  event  actual forecast previous
# 0               Namibia - Heritage Day    None     None     None
# ...

# %%
# 환율
data = investpy.get_currency_cross_historical_data(currency_cross='USD/KRW', from_date='01/01/2020', to_date='24/09/2020')
data.head()
# Out:
#                Open     High      Low    Close Currency
# Date
# 2020-01-01  1155.07  1155.56  1154.23  1155.02      KRW
# 2020-01-02  1154.62  1160.93  1153.66  1157.94      KRW
# 2020-01-03  1158.85  1169.24  1156.27  1165.95      KRW
# 2020-01-06  1165.51  1173.41  1165.48  1167.56      KRW
# 2020-01-07  1167.54  1169.15  1163.70  1168.30      KRW

# %%
data.sort_index(ascending=False)
# Out:
#                Open     High      Low    Close Currency
# Date
# 2020-09-24  1170.63  1174.78  1167.50  1174.23      KRW
# 2020-09-23  1163.65  1172.46  1160.69  1170.65      KRW
# 2020-09-22  1164.84  1166.03  1158.93  1163.61      KRW
# 2020-09-21  1165.00  1168.31  1156.46  1163.61      KRW
# 2020-09-18  1169.70  1170.78  1159.40  1164.81      KRW
# ...             ...      ...      ...      ...      ...
# 2020-01-07  1167.54  1169.15  1163.70  1168.30      KRW
# 2020-01-06  1165.51  1173.41  1165.48  1167.56      KRW
# 2020-01-03  1158.85  1169.24  1156.27  1165.95      KRW
# 2020-01-02  1154.62  1160.93  1153.66  1157.94      KRW
# 2020-01-01  1155.07  1155.56  1154.23  1155.02      KRW
#
# [192 rows x 5 columns]

# %%
# 원달러 환율, 1995년~현재
df = fdr.DataReader('USD/KRW', '1995')
df['Close'].plot()

# %%
df
# Out:
#               Close     Open     High      Low  Change
# Date
# 1995-01-02   788.50   788.50   788.50   788.50  0.0000
# 1995-01-03   788.65   788.05   788.85   787.55  0.0002
# 1995-01-04   789.95   788.65   790.05   788.45  0.0016
# 1995-01-05   789.90   789.80   790.20   789.30 -0.0001
# 1995-01-06   791.55   789.75   791.65   789.65  0.0021
# ...             ...      ...      ...      ...     ...
# 2020-09-18  1164.81  1169.70  1170.78  1159.40 -0.0038
# 2020-09-21  1163.61  1165.00  1168.31  1156.46 -0.0010
# 2020-09-22  1163.61  1164.84  1166.03  1158.93  0.0000
# 2020-09-23  1170.65  1163.65  1172.46  1160.69  0.0061
# 2020-09-24  1174.24  1170.63  1174.78  1167.50  0.0031
#
# [6704 rows x 5 columns]

# %%
df = fdr.DataReader('KRW/USD', '2020-09')

# %%
df
# Out:
#                Close      Open      High       Low  Change
# Date
# 2020-09-01  0.000844  0.000842  0.000846  0.000842  0.0014
# 2020-09-02  0.000841  0.000844  0.000844  0.000840 -0.0035
# 2020-09-03  0.000839  0.000841  0.000843  0.000839 -0.0013
# 2020-09-04  0.000842  0.000839  0.000842  0.000839  0.0024
# 2020-09-06  0.000842  0.000842  0.000842  0.000842  0.0008
# 2020-09-07  0.000842  0.000842  0.000843  0.000841 -0.0008
# 2020-09-08  0.000840  0.000842  0.000843  0.000840 -0.0013
# 2020-09-09  0.000844  0.000840  0.000844  0.000840  0.0044
# 2020-09-10  0.000842  0.000844  0.000844  0.000842 -0.0019
# 2020-09-11  0.000842  0.000842  0.000843  0.000841  0.0000
# 2020-09-13  0.000842  0.000842  0.000842  0.000842 -0.0008
# 2020-09-14  0.000846  0.000841  0.000847  0.000841  0.0055
# 2020-09-15  0.000847  0.000846  0.000849  0.000845  0.0011
# 2020-09-16  0.000852  0.000847  0.000854  0.000846  0.0060
# 2020-09-17  0.000855  0.000852  0.000856  0.000849  0.0033
# ...
