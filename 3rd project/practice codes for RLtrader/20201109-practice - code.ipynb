# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
reward_df = pd.read_csv('./data/Results/6. epoch_10time_A35720_20201109/train_re_20201109/reward_20201109.csv')

# %%
reward_df
# Out:
#          0
# 0  22.2309
# 1   0.0000
# 2  37.4947
# 3  58.2061
# 4  59.2910
# 5  38.4248
# 6  71.2606
# 7   0.0000
# 8  78.8853
# 9  74.9242

# %%
plt.figure(figsize=(10, 5))
plt.plot(reward_df, 'g',  label='profit(%)')
plt.title('Profit rate _ kakao train 10 Epochs')
plt.legend()
plt.ylabel('final profit(%)')
plt.xlabel('Epoch')
plt.savefig('kakao_profit_train_10epochs.png', dpi=300)
plt.show()

# %%
reward_df = pd.read_csv('./data/Results/6. epoch_10time_A35720_20201109/test_re_20201109/reward.csv')

# %%
plt.figure(figsize=(10, 5))
plt.plot(reward_df, 'r',  label='epoch10 model')
plt.plot(reward_df2, 'b--',  label='epoch100 model')
plt.title('Profit rate _ kakao test')
plt.legend()
plt.ylabel('final profit(%)')
plt.xlabel('Epoch')
plt.savefig('kakao_profit_test_10epoch model_compared.png', dpi=300)
plt.show()

# %%
reward_df2 = pd.read_csv('./data/Results/1. ref_ A035720_20201108/Test_re_20201108/reward.csv')
