# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### investing 페이지 뉴스 헤드라인 불러오기(by jhshin)

# %%
import random
import urllib.request
import urllib.parse
from bs4 import BeautifulSoup
import time
import csv

# %%
header = {'User-Agent': 'Mozilla/5.0'}
pageNum = 1
saveTocsv = []
tmp = []

while pageNum:
    url = f'https://kr.investing.com/news/stock-market-news/{pageNum}'

    request = urllib.request.Request(url, headers=header)
    html = urllib.request.urlopen(request).read()
    soup = BeautifulSoup(html, 'html.parser')

    title = soup.find_all(class_="js-external-link title")

    for i in title:
        print(i.attrs['href'])
        print(i.attrs['title'])

        tmp = [[i.attrs['href']],[i.attrs['title']]]
        saveTocsv.append(tmp)



    with open('saved.csv', 'w', encoding='utf-8', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(['link', 'title'])
        writer.writerow(saveTocsv)

    pageNum += 1
    print(str(pageNum)+'페이지 완료')
    time.sleep(random.uniform(1,10))
# Out:
# https://invst.ly/s7ix3
# IBK기업은행, 국내 최초 'AI 부동산 자동심사 시스템' 도입
# https://invst.ly/s7ix0
# 삼광글라스, 23일 추석특집 올데이 라이브 방송
# https://invst.ly/s7iwy
# 교보생명, 한층 똑똑해진 AI 챗봇 '러버스 2.0' 오픈
# https://invst.ly/s7iu1
# [특징주] 신풍제약, 2100억 규모 자사주 처분에 급락
# https://invst.ly/s7iu7
# [특징주] 박셀바이오, 코스닥 상장 첫날 하락세
# https://invst.ly/s7iuq
# 하이트진로, 소방유가족 지원금 전달…꾸준한 인연 이어가
# https://invst.ly/s7iuo
# JTI코리아, ‘메비우스 LBS 트로피컬 믹스’ 출시
# https://invst.ly/s7it-
# [특징주] 박셀바이오, 코스닥 입성일에 20% 하락
# https://invst.ly/s7ivc
# [특징주] 삼성바이오로직스, 3천억원대 의약품 위탁생산 계약에 강세
# https://invst.ly/s7iun
# [특징주] 박셀바이오, 코스닥 상장 첫날 급락…공모가 밑돌아
# https://invst.ly/s7ium
# 강승조 이글벳 회장, 사랑의열매 아너 소사이어티 가입
# https://invst.ly/s7isq
# NH투자증권, 부산 디지털 자산관리센터 신설
# https://invst.ly/s7isr
# 최태원의 승부수… SK그룹, 美 실리콘밸리서 AI 자회사 출범
# https://invst.ly/s7iup
# HDC현대산업개발·롯데건설 ‘반정 아이파크 캐슬 5단지’ 10월 분양
# https://invst.ly/s7isu
# 랩지노믹스, 美언론 진단키트 신뢰도 불신 보도에 급락
# https://invst.ly/s7ivf
# [특징주]나라엠앤디, LG화학 2차전지 배터리팩 공급사…LG전자가 2대주주 강세
# 2페이지 완료
# https://invst.ly/s7isw
# ...

# %% [markdown]
# ### investpy module practice

# %%
import investpy

# %%
# Retrieve all the available stocks as a Python list
stocks = investpy.get_stocks_list()

# %%
len(stocks)
# Out:
# 39952

# %%
# Retrieve the recent historical data (past month) of a stock as a pandas.DataFrame on ascending date order
df = investpy.get_stock_recent_data(stock='bbva', country='spain', as_json=False, order='ascending')
df.head()
# Out:
#              Open   High    Low  Close    Volume Currency
# Date
# 2020-08-24  2.453  2.484  2.415  2.484  15737400      EUR
# 2020-08-25  2.510  2.584  2.503  2.505  28033600      EUR
# 2020-08-26  2.491  2.570  2.480  2.541  26362800      EUR
# 2020-08-27  2.525  2.545  2.466  2.534  18903100      EUR
# 2020-08-28  2.557  2.629  2.546  2.600  25572600      EUR

# %%
# Retrieve the recent historical data (past month) of a stock as a pandas.DataFrame on ascending date order
df = investpy.get_stock_recent_data(stock='aapl', country='United States', as_json=False, order='ascending')
df.head()
# Out:
#               Open    High     Low   Close     Volume Currency
# Date
# 2020-08-24  128.70  128.79  123.94  125.86  345937984      USD
# 2020-08-25  124.70  125.18  123.05  124.82  211496000      USD
# 2020-08-26  126.18  126.99  125.08  126.52  163022000      USD
# 2020-08-27  127.14  127.49  123.83  125.01  155552000      USD
# 2020-08-28  126.01  126.44  124.58  124.81  187630000      USD

# %%
# Retrieve the company profile of the introduced stock on english
profile = investpy.get_stock_company_profile(stock='bbva', country='spain', language='english')
profile
# Out:
# {'url': 'https://www.investing.com/equities/bbva-company-profile',
#  'desc': 'Banco Bilbao Vizcaya Argentaria, S.A. (BBVA) is a Spain - based bank. It is a diversified financial company engaged in retail banking, wholesale banking, asset management and private banking. Its segments are: Spain, the United States, Turkey, Mexico, South America and Rest of Eurasia. The activities in Spain are banking activity and Insurance. In the United States it offers services through, BBVA USA and the BBVA New York branch. The Turkey segment is represented by the group Garanti BBVA, an integrated financial services group, that also operate in Holland and Romania. The Mexico segment activities include banking and insurance businesses. In South America, it provides banking and insurance businesses. The Rest of Eurasia segment includes business activity in the rest of Europe and Asia'}

# %%
df = investpy.get_stock_historical_data(stock='aapl',
                                        country='United States',
                                        from_date='01/01/2010',
                                        to_date='22/09/2020')

# %%
df
# Out:
#               Open    High     Low   Close     Volume Currency
# Date
# 2010-01-04    7.62    7.66    7.58    7.64  493728704      USD
# 2010-01-05    7.66    7.70    7.62    7.66  601904640      USD
# 2010-01-06    7.66    7.69    7.53    7.53  552158912      USD
# 2010-01-07    7.56    7.57    7.47    7.52  477129760      USD
# 2010-01-08    7.51    7.57    7.47    7.57  447876768      USD
# ...            ...     ...     ...     ...        ...      ...
# 2020-09-15  118.52  118.52  113.64  115.54  184642032      USD
# 2020-09-16  115.20  115.94  112.08  112.13  155026672      USD
# 2020-09-17  109.41  112.18  108.80  110.34  178010976      USD
# 2020-09-18  110.40  110.88  106.09  106.84  287104992      USD
# 2020-09-21  104.34  110.12  103.50  110.08  195713808      USD
#
# [2699 rows x 6 columns]

# %%
df = investpy.get_stock_historical_data(stock='mmm',
                                        country='United States',
                                        from_date='01/01/2010',
                                        to_date='22/09/2020')

# %%
df.sort_values(by='Open', ascending=False)
# Out:
#               Open    High     Low   Close   Volume Currency
# Date
# 2018-01-29  258.51  259.34  255.97  256.01  2306292      USD
# 2018-01-30  255.60  255.69  251.41  251.54  2412632      USD
# 2018-01-26  253.43  259.77  253.39  258.63  3730628      USD
# 2018-01-31  251.49  253.13  249.60  250.50  3136406      USD
# 2018-01-25  250.00  254.80  247.10  252.36  3507873      USD
# ...            ...     ...     ...     ...      ...      ...
# 2011-10-06   72.72   74.69   72.00   74.65  4835766      USD
# 2011-09-23   72.64   74.33   72.34   73.99  4583749      USD
# 2011-10-05   71.74   72.84   71.01   72.53  5468927      USD
# 2011-10-03   71.13   73.24   70.93   70.93  7619527      USD
# 2011-10-04   70.13   72.18   68.63   72.01  8689888      USD
#
# [2698 rows x 6 columns]

# %%
data = investpy.economic_calendar()
data.head(10)
# Out:
#        id        date     time           zone currency importance  \
# 0      88  22/09/2020  All Day          japan     None       None
# 1     173  22/09/2020  All Day       bulgaria     None       None
# 2  414703  22/09/2020    00:30  united states      USD        low
# 3  414704  22/09/2020    00:30  united states      USD        low
# 4  415019  22/09/2020    01:00  united states      USD     medium
# 5  413510  22/09/2020    06:00    south korea      KRW        low
# 6  413509  22/09/2020    06:00    south korea      KRW        low
# 7  415158  22/09/2020    07:00  united states      USD     medium
# 8  414966  22/09/2020    07:00  united states      USD     medium
# 9  414934  22/09/2020    09:30      australia      AUD     medium
#
#                            event  actual forecast previous
# 0         Japan - Autumn Equinox    None     None     None
# 1    Bulgaria - Independence Day    None     None     None
# 2           3-Month Bill Auction  0.100%     None   0.110%
# ...

# %%
df = investpy.get_stock_historical_data(stock='035720',
                                        country='south korea',
                                        from_date='01/01/1900',
                                        to_date='23/09/2020')

# %%
df
# Out:
#                 Open      High       Low     Close  Volume Currency
# Date
# 2014-03-14   69700.0   77200.0   69500.0   76500.0  531434      KRW
# 2014-03-17   76000.0   77500.0   74800.0   76000.0  194075      KRW
# 2014-03-18   76200.0   76600.0   75000.0   76100.0  122992      KRW
# 2014-03-19   76600.0   80200.0   75400.0   79800.0  274819      KRW
# 2014-03-20   79000.0   80200.0   77600.0   79800.0  128509      KRW
# ...              ...       ...       ...       ...     ...      ...
# 2020-09-18  369000.0  377000.0  366000.0  373000.0  488767      KRW
# 2020-09-20  373000.0  373000.0  373000.0  373000.0       0      KRW
# 2020-09-21  371500.0  373000.0  364000.0  364500.0     573      KRW
# 2020-09-22  361500.0  369000.0  351500.0  353000.0      38      KRW
# 2020-09-23  358500.0  367000.0  353000.0  365500.0  913110      KRW
#
# [1808 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1808 entries, 2014-03-14 to 2020-09-23
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Open      1808 non-null   float64
#  1   High      1808 non-null   float64
#  2   Low       1808 non-null   float64
#  3   Close     1808 non-null   float64
#  4   Volume    1808 non-null   int64
#  5   Currency  1808 non-null   object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 91.8+ KB

# %%
list(df.index)
# Out:
# [Timestamp('2014-03-14 00:00:00'),
#  Timestamp('2014-03-17 00:00:00'),
#  Timestamp('2014-03-18 00:00:00'),
#  Timestamp('2014-03-19 00:00:00'),
#  Timestamp('2014-03-20 00:00:00'),
#  Timestamp('2014-03-21 00:00:00'),
#  Timestamp('2014-03-24 00:00:00'),
#  Timestamp('2014-03-25 00:00:00'),
#  Timestamp('2014-03-26 00:00:00'),
#  Timestamp('2014-03-27 00:00:00'),
#  Timestamp('2014-03-28 00:00:00'),
#  Timestamp('2014-03-31 00:00:00'),
#  Timestamp('2014-04-01 00:00:00'),
#  Timestamp('2014-04-02 00:00:00'),
#  Timestamp('2014-04-03 00:00:00'),
#  Timestamp('2014-04-04 00:00:00'),
#  Timestamp('2014-04-07 00:00:00'),
#  Timestamp('2014-04-08 00:00:00'),
#  Timestamp('2014-04-09 00:00:00'),
#  Timestamp('2014-04-10 00:00:00'),
#  Timestamp('2014-04-11 00:00:00'),
#  Timestamp('2014-04-14 00:00:00'),
#  Timestamp('2014-04-15 00:00:00'),
#  Timestamp('2014-04-16 00:00:00'),
#  Timestamp('2014-04-17 00:00:00'),
#  Timestamp('2014-04-18 00:00:00'),
#  Timestamp('2014-04-21 00:00:00'),
# ...

# %%
df['date']= df.index

# %%
df.head()
# Out:
#                Open     High      Low    Close  Volume Currency       date
# Date
# 2014-03-14  69700.0  77200.0  69500.0  76500.0  531434      KRW 2014-03-14
# 2014-03-17  76000.0  77500.0  74800.0  76000.0  194075      KRW 2014-03-17
# 2014-03-18  76200.0  76600.0  75000.0  76100.0  122992      KRW 2014-03-18
# 2014-03-19  76600.0  80200.0  75400.0  79800.0  274819      KRW 2014-03-19
# 2014-03-20  79000.0  80200.0  77600.0  79800.0  128509      KRW 2014-03-20

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1808 entries, 2014-03-14 to 2020-09-23
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Open      1808 non-null   float64
#  1   High      1808 non-null   float64
#  2   Low       1808 non-null   float64
#  3   Close     1808 non-null   float64
#  4   Volume    1808 non-null   int64
#  5   Currency  1808 non-null   object
#  6   date      1808 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 105.9+ KB

# %%
df['date'].astype('str')
# Out:
# Date
# 2014-03-14    2014-03-14
# 2014-03-17    2014-03-17
# 2014-03-18    2014-03-18
# 2014-03-19    2014-03-19
# 2014-03-20    2014-03-20
#                  ...
# 2020-09-18    2020-09-18
# 2020-09-20    2020-09-20
# 2020-09-21    2020-09-21
# 2020-09-22    2020-09-22
# 2020-09-23    2020-09-23
# Name: date, Length: 1808, dtype: object

# %% [markdown]
# ### 크롤링 데이터 양식

# %%
pd.read_csv('./news_000270.csv', index_col=0)
# Out:
#                                            제목  \
# 0     상품성 높이고도 2000만원대 맞춘 기아차 '스포티지'..오늘부터 판매
# 1         디자인에 편의성까지 잡았다...기아차 '2021 스포티지' 출시
# 2                 기아차 ‘2021 스포티지’ 출시…2376만원부터
# 3                  기아차, 업그레이드한 ‘2021 스포티지’ 출시
# 4        블랙 테마 트림에 편의사양 강화…기아차 '2021 스포티지' 출시
# ...                                       ...
# 4688         [특징주]기아차, 신차 흥행에 따른 실적 개선 전망에 강세
# 4689             기아차, 신차 연달아 흥행 가도..목표가 상향-신한
# 4690             기아차, 신차 판매 호조세...목표가↑-신한금융투자
# 4696       "기아차, 내수 판매 회복으로 실적 개선 기대···목표주가↑"
# 4697                 현대·기아차 디자인 이끄는 'ACCD 동문'
#
#                                                      링크      기관          날짜  \
# 0     https://finance.naver.com/item/news_read.nhn?a...   머니투데이  2020.09.22
# 1     https://finance.naver.com/item/news_read.nhn?a...  파이낸셜뉴스  2020.09.22
# 2     https://finance.naver.com/item/news_read.nhn?a...   헤럴드경제  2020.09.22
# 3     https://finance.naver.com/item/news_read.nhn?a...    이데일리  2020.09.22
# ...

# %%
pd.read_csv('./upjong_code.csv', index_col=0)
# Out:
#         종목코드                      종목명            업종 코스닥여부
# 0     000020                     동화약품            제약     N
# 1     000040                    KR모터스           자동차     N
# 2     000050                       경방  섬유,의류,신발,호화품     N
# 3     000060                    메리츠화재          손해보험     N
# 4     000070                    삼양홀딩스            식품     N
# ...      ...                      ...           ...   ...
# 1556  590018       미래에셋 중국 심천 100 ETN            기타     N
# 1557  590012       미래에셋 글로벌 리츠 ETN(H)            기타     N
# 1558  700001  하나 코스피 변동성추세 추종 양매도 ETN            기타     N
# 1559  900140                 엘브이엠씨홀딩스           자동차     N
# 1560     NaN                      NaN           NaN   NaN
#
# [1561 rows x 4 columns]
